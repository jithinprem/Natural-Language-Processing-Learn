# %% [markdown]
# # Part of Speech Tagging and named entity....

# %% [markdown]
# - understand how to retrive parts-of-speech using Spacy
# - named entity recog
# - visualize pos and ner
# - sentence segmentation

# %% [markdown]
# - most words are rare
# - some same type has huge difference
# - some different have same meaning

# %% [markdown]
# - splitting text into word-like units is difficult
# - use linguistic knowledge to add useful information

# %% [markdown]
# - you need to know atleast noun vs verb vs ajective
# - plural noun pasttense superlativeadjective

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(u"the quick brown fox jumped over the lazy dog's back.")

# %%
print(doc.text)
# Out:
# the quick brown fox jumped over the lazy dog's back.

# %%
print(doc[4].text)
# Out:
# jumped

# %%
print(doc[4].pos_)
# Out:
# VERB

# %%
print(doc[4].tag_)
# Out:
# VBD

# %% [markdown]
# ## Fine-grained Part of- speech Tags

# %% [markdown]
# ### Refer to the notebooks provided to see what it means

# %%
for token in doc:
    print(f'{token.text:{10}} {token.pos_:{15}} {token.tag_:{15}} {spacy.explain(token.tag_)}')
# Out:
# the        DET             DT              determiner
# quick      ADJ             JJ              adjective (English), other noun-modifier (Chinese)
# brown      ADJ             JJ              adjective (English), other noun-modifier (Chinese)
# fox        NOUN            NN              noun, singular or mass
# jumped     VERB            VBD             verb, past tense
# over       ADP             IN              conjunction, subordinating or preposition
# the        DET             DT              determiner
# lazy       ADJ             JJ              adjective (English), other noun-modifier (Chinese)
# dog        NOUN            NN              noun, singular or mass
# 's         PART            POS             possessive ending
# back       ADV             RB              adverb
# .          PUNCT           .               punctuation mark, sentence closer

# %%
doc = nlp(u'I read books on NLP.')

# %%
word = doc[1]
word.text
# Out:
# 'read'

# %%
token= word
print(f'{token.text:{8}} {token.pos_:{8}} {token.tag_:{8}} {spacy.explain(token.tag_):{15}}')
# Out:
# read     VERB     VBP      verb, non-3rd person singular present

# %%
doc = nlp(u'I read a book on NLP')

# %%
word = doc[1]
token = word
print(f'{token.text:{8}} {token.pos_:{10}} {token.tag_:{10}} {spacy.explain(token.tag_)}')
# Out:
# read     VERB       VBP        verb, non-3rd person singular present

# %%
doc = nlp(u'The quick brown fox  jumped over the lazy dog\'s back.')

# %%
# observe here it tells the tag, and tell how many similar tags are in the sent


POS_counts = doc.count_by(spacy.attrs.POS)

# %%
POS_counts
# Out:
# {90: 2, 84: 3, 92: 2, 103: 1, 100: 1, 85: 1, 94: 1, 86: 1, 97: 1}

# %%
doc[0].pos
# Out:
# 90

# %%
doc[0]
# Out:
# The

# %%
POS_counts = doc.count_by(spacy.attrs.POS)

for k, val in sorted(POS_counts.items()):
    print(f'{k}.  {doc.vocab[k].text:{5}} ---> {val}')
# Out:
# 84.  ADJ   ---> 54
# 85.  ADP   ---> 122
# 86.  ADV   ---> 67
# 87.  AUX   ---> 49
# 89.  CCONJ ---> 61
# 90.  DET   ---> 90
# 92.  NOUN  ---> 166
# 93.  NUM   ---> 8
# 94.  PART  ---> 29
# 95.  PRON  ---> 109
# 96.  PROPN ---> 76
# 97.  PUNCT ---> 173
# 98.  SCONJ ---> 20
# 100.  VERB  ---> 135
# 103.  SPACE ---> 99

# %%
TAG_counts = doc.count_by(spacy.attrs.TAG)

for k, v in sorted(TAG_counts.items()):
    print(f'{k}.  {doc.vocab[k].text:{5}}  {v}')
# Out:
# 74.  POS    1
# 164681854541413346.  RB     1
# 1292078113972184607.  IN     1
# 6893682062797376370.  _SP    1
# 10554686591937588953.  JJ     3
# 12646065887601541794.  .      1
# 15267657372422890137.  DT     2
# 15308085513773655218.  NN     2
# 17109001835818727656.  VBD    1

# %%
# dep is used for syntantic dependency

DEP_counts = doc.count_by(spacy.attrs.DEP)   
for k, v in sorted(DEP_counts.items()):
    print(f'{k}.   {doc.vocab[k].text:{5}}   {v}')
# Out:
# 402.   amod    3
# 414.   dep     1
# 415.   det     2
# 429.   nsubj   1
# 439.   pobj    1
# 440.   poss    1
# 443.   prep    1
# 445.   punct   1
# 8110129090154140942.   case    1
# 8206900633647566924.   ROOT    1

# %% [markdown]
# ## Visualization Oart if Speech

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(u'The quick brown fox jumped over the lazy dog')

# %%
from spacy import displacy

# %%
displacy.render(doc, style = 'dep', jupyter = True, options ={'distance':110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="15173afb7f2c4ff1988d41a6724cb02b-0" class="displacy" width="1040" height="302.0" direction="ltr" style="max-width: none; height: 302.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">quick</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">brown</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">fox</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">jumped</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">over</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">lazy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">dog</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-15173afb7f2c4ff1988d41a6724cb02b-0-0" stroke-width="2px" d="M70,167.0 C70,2.0 380.0,2.0 380.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-15173afb7f2c4ff1988d41a6724cb02b-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,169.0 L62,157.0 78,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-15173afb7f2c4ff1988d41a6724cb02b-0-1" stroke-width="2px" d="M180,167.0 C180,57.0 375.0,57.0 375.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-15173afb7f2c4ff1988d41a6724cb02b-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M180,169.0 L172,157.0 188,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-15173afb7f2c4ff1988d41a6724cb02b-0-2" stroke-width="2px" d="M290,167.0 C290,112.0 370.0,112.0 370.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-15173afb7f2c4ff1988d41a6724cb02b-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290,169.0 L282,157.0 298,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-15173afb7f2c4ff1988d41a6724cb02b-0-3" stroke-width="2px" d="M400,167.0 C400,112.0 480.0,112.0 480.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-15173afb7f2c4ff1988d41a6724cb02b-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400,169.0 L392,157.0 408,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-15173afb7f2c4ff1988d41a6724cb02b-0-4" stroke-width="2px" d="M510,167.0 C510,112.0 590.0,112.0 590.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-15173afb7f2c4ff1988d41a6724cb02b-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M590.0,169.0 L598.0,157.0 582.0,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-15173afb7f2c4ff1988d41a6724cb02b-0-5" stroke-width="2px" d="M730,167.0 C730,57.0 925.0,57.0 925.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-15173afb7f2c4ff1988d41a6724cb02b-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M730,169.0 L722,157.0 738,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-15173afb7f2c4ff1988d41a6724cb02b-0-6" stroke-width="2px" d="M840,167.0 C840,112.0 920.0,112.0 920.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-15173afb7f2c4ff1988d41a6724cb02b-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M840,169.0 L832,157.0 848,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-15173afb7f2c4ff1988d41a6724cb02b-0-7" stroke-width="2px" d="M620,167.0 C620,2.0 930.0,2.0 930.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-15173afb7f2c4ff1988d41a6724cb02b-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M930.0,169.0 L938.0,157.0 922.0,157.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
# other options that you can pass

# %%
options = {'distanc': 110, 'compact': 'True', 'color':'yellow', 'bg':'#09a3d5', 'font':'Times'}

# %%
displacy.render(doc, style= 'dep', jupyter=True, options= options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="24cac11dfb7942dbab43bd96521ffd47-0" class="displacy" width="1400" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: yellow; background: #09a3d5; font-family: Times; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">quick</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">brown</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">fox</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">jumped</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">over</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">lazy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">dog</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-24cac11dfb7942dbab43bd96521ffd47-0-0" stroke-width="2px" d="M62,227.0 62,152.0 500.0,152.0 500.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-24cac11dfb7942dbab43bd96521ffd47-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,229.0 L58,221.0 66,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-24cac11dfb7942dbab43bd96521ffd47-0-1" stroke-width="2px" d="M212,227.0 212,177.0 497.0,177.0 497.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-24cac11dfb7942dbab43bd96521ffd47-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,229.0 L208,221.0 216,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-24cac11dfb7942dbab43bd96521ffd47-0-2" stroke-width="2px" d="M362,227.0 362,202.0 494.0,202.0 494.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-24cac11dfb7942dbab43bd96521ffd47-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,229.0 L358,221.0 366,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-24cac11dfb7942dbab43bd96521ffd47-0-3" stroke-width="2px" d="M512,227.0 512,202.0 644.0,202.0 644.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-24cac11dfb7942dbab43bd96521ffd47-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M512,229.0 L508,221.0 516,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-24cac11dfb7942dbab43bd96521ffd47-0-4" stroke-width="2px" d="M662,227.0 662,202.0 794.0,202.0 794.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-24cac11dfb7942dbab43bd96521ffd47-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M794.0,229.0 L798.0,221.0 790.0,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-24cac11dfb7942dbab43bd96521ffd47-0-5" stroke-width="2px" d="M962,227.0 962,177.0 1247.0,177.0 1247.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-24cac11dfb7942dbab43bd96521ffd47-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M962,229.0 L958,221.0 966,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-24cac11dfb7942dbab43bd96521ffd47-0-6" stroke-width="2px" d="M1112,227.0 1112,202.0 1244.0,202.0 1244.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-24cac11dfb7942dbab43bd96521ffd47-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1112,229.0 L1108,221.0 1116,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-24cac11dfb7942dbab43bd96521ffd47-0-7" stroke-width="2px" d="M812,227.0 812,152.0 1250.0,152.0 1250.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-24cac11dfb7942dbab43bd96521ffd47-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1250.0,229.0 L1254.0,221.0 1246.0,221.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
# for dealing with large sentences it's better to deal with a list of spans

# %%
doc2 = nlp(u'This is a sentence. This is another sentence, possibly longer than the previous sentence')

# %%
spans = list(doc2.sents)

# %%
spans
# Out:
# [This is a sentence.,
#  This is another sentence, possibly longer than the previous sentence]

# %%
displacy.render(spans, style='dep', options= {'distance':110})

## to display in a local host :
# displacy.serve(doc2, style='dep', options= {'distance':110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="500ca22d899445cd9fd6a2d359332a91-0" class="displacy" width="490" height="247.0" direction="ltr" style="max-width: none; height: 247.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">sentence.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-500ca22d899445cd9fd6a2d359332a91-0-0" stroke-width="2px" d="M70,112.0 C70,57.0 155.0,57.0 155.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-500ca22d899445cd9fd6a2d359332a91-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,114.0 L62,102.0 78,102.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-500ca22d899445cd9fd6a2d359332a91-0-1" stroke-width="2px" d="M290,112.0 C290,57.0 375.0,57.0 375.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-500ca22d899445cd9fd6a2d359332a91-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290,114.0 L282,102.0 298,102.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-500ca22d899445cd9fd6a2d359332a91-0-2" stroke-width="2px" d="M180,112.0 C180,2.0 380.0,2.0 380.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-500ca22d899445cd9fd6a2d359332a91-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M380.0,114.0 L388.0,102.0 372.0,102.0" fill="currentColor"/>
# </g>
# </svg>
#
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="500ca22d899445cd9fd6a2d359332a91-1" class="displacy" width="1150" height="302.0" direction="ltr" style="max-width: none; height: 302.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">another</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">sentence,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">possibly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">longer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">than</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">previous</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">sentence</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-500ca22d899445cd9fd6a2d359332a91-1-0" stroke-width="2px" d="M70,167.0 C70,112.0 150.0,112.0 150.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-500ca22d899445cd9fd6a2d359332a91-1-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,169.0 L62,157.0 78,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-500ca22d899445cd9fd6a2d359332a91-1-1" stroke-width="2px" d="M290,167.0 C290,112.0 370.0,112.0 370.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-500ca22d899445cd9fd6a2d359332a91-1-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290,169.0 L282,157.0 298,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-500ca22d899445cd9fd6a2d359332a91-1-2" stroke-width="2px" d="M180,167.0 C180,57.0 375.0,57.0 375.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-500ca22d899445cd9fd6a2d359332a91-1-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M375.0,169.0 L383.0,157.0 367.0,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-500ca22d899445cd9fd6a2d359332a91-1-3" stroke-width="2px" d="M510,167.0 C510,112.0 590.0,112.0 590.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-500ca22d899445cd9fd6a2d359332a91-1-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor"

# %% [markdown]
# ## Named Entity-Recognition

# %% [markdown]
# - named-entity recognition
#  - locate and classify named entity (person name, organization, location, quantities, monetary val)
#  -

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
def show_ents(doc):
    if doc.ents:
        for ent in doc.ents:
            print(ent.text + ' - ' + ent.label_ + ' - ' + str(spacy.explain(ent.label_)))
    else:
        print('No entities found !')

# %%
doc = nlp(u'Hi how are you?')

# %%
show_ents(doc)
# Out:
# No entities found !

# %%
doc = nlp(u'May I go to Washington, DC next May to see the Washington Monumment?')
show_ents(doc)
# Out:
# Washington, DC - GPE - Countries, cities, states
# next May - DATE - Absolute or relative dates or periods
# the Washington Monumment - ORG - Companies, agencies, institutions, etc.

# %%
 doc = nlp(u"Can I please have 500 dollars of Microsoft stock?")

# %%
show_ents(doc)
# Out:
# 500 dollars - MONEY - Monetary values, including unit
# Microsoft - ORG - Companies, agencies, institutions, etc.

# %% [markdown]
# #### Adding custom named entity

# %%
doc = nlp(u"Tesla to build a U.K. factory for $6 million")

# %%
show_ents(doc)
# Out:
# U.K. - GPE - Countries, cities, states
# $6 million - MONEY - Monetary values, including unit

# %%
from spacy.tokens import Span

# %%
ORG = doc.vocab.strings[u"ORG"]

# %%
ORG
# Out:
# 383

# %%
new_ent = Span(doc, 0,1, label = ORG)

# %%
doc.ents = list(doc.ents) + [new_ent]

# %%
show_ents(doc)
# Out:
# Tesla - ORG - Companies, agencies, institutions, etc.
# U.K. - GPE - Countries, cities, states
# $6 million - MONEY - Monetary values, including unit

# %%
doc2 = nlp(u"Tesla has a huge office")

# %%
show_ents(doc2)
# Out:
# No entities found !

# %%
# think why is it showing no entities, maybe we just added it as an entity to only doc

# %% [markdown]
# ### Adding named entities

# %% [markdown]
# - add several terms as entity
# - suppose you in vaccum comapny , so vaccum-cleaner and vaccumcleaner  all are entities

# %%
doc = nlp(u'Our company created a brand new vaccum cleaner .'
         u'this new vaccum-cleaner is the best in show')

# %%
show_ents(doc)
# Out:
# No entities found !

# %%
from spacy.matcher import PhraseMatcher

# %%
matcher = PhraseMatcher(nlp.vocab)

# %%
phrase_list  = ['vaccum cleaner', 'vaccum-cleaner']

# %%
phrase_patterns = [nlp(text) for text in phrase_list]

# %%
phrase_patterns
# Out:
# [vaccum cleaner, vaccum-cleaner]

# %%
matcher.add("newproduct", phrase_patterns)

# %%
found_match = matcher(doc)

# %%
found_match
# Out:
# [(2689272359382549672, 6, 8), (2689272359382549672, 10, 13)]

# %%
from spacy.tokens import Span

# %%
PROD = doc.vocab.strings[u'PRODUCT']

# %%
found_match
# Out:
# [(2689272359382549672, 6, 8), (2689272359382549672, 10, 13)]

# %%
new_ents = [Span(doc , match[1], match[2], label=PROD) for match in found_match]

# %%
doc.ents = list(doc.ents) + new_ents

# %%
show_ents(doc)
# Out:
# vaccum cleaner - PRODUCT - Objects, vehicles, foods, etc. (not services)
# vaccum-cleaner - PRODUCT - Objects, vehicles, foods, etc. (not services)

# %%
doc = nlp(u"Originally I paid $29.95 for this car toy, but now it's marked down by $10 ")

# %%
ents = [(ent) for ent in doc.ents]

# %%
ents
# Out:
# [29.95, 10]

# %%
# only show a specified entity

[ent for ent in doc.ents if ent.label_ == "MONEY"]
# Out:
# [29.95, 10]

# %% [markdown]
# ### Named entity recognition

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
from spacy import displacy

# %%
doc = nlp(u'Over the last quarter Apple sold nearly 20 thousand iPods for a profit of $6 million. By contrast sony only sold 8 thousand cardinal walkman music players')

# %%
displacy.render(doc, style= 'ent', jupyter= True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sold
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly 20 thousand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     iPods
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  for a profit of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $6 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# . By contrast
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sony
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  only sold
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8 thousand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  cardinal walkman music players</div></span>

# %%
for sent in doc.sents:
    displacy.render(nlp(sent.text), style= 'ent')
    print('------------')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sold
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly 20 thousand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     iPods
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  for a profit of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $6 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# .</div></span>
# ------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">By contrast
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sony
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  only sold
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8 thousand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  cardinal walkman music players</div></span>
# ------------

# %%
colors = {'ORG': 'linear-gradient(45deg, blue, green)'}
options = {'ents' : ['PRODUCT', 'ORG'], 'colors':colors}

# %%
displacy.render(doc, style='ent', jupyter= True, options= options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Over the last quarter
# <mark class="entity" style="background: linear-gradient(45deg, blue, green); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sold nearly 20 thousand
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     iPods
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  for a profit of $6 million. By contrast
# <mark class="entity" style="background: linear-gradient(45deg, blue, green); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sony
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  only sold 8 thousand cardinal walkman music players</div></span>

# %% [markdown]
# ## Sentence Segmentation

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(u'This is the first sentence. This is another sentence. This is the last sentence. ')

# %%
for sent in doc.sents:
    print(sent)
# Out:
# This is the first sentence.
# This is another sentence.
# This is the last sentence.

# %%
doc[0]
# Out:
# This

# %%
# this is how to take the individual sentences from it

sentences =list(doc.sents)

# %%
sentences
# Out:
# [This is the first sentence.,
#  This is another sentence.,
#  This is the last sentence.]

# %%
doc = nlp(u'"Management is doing the right things; leadership is doing the right things." -Peater Ducker')

# %%
doc.text
# Out:
# '"Management is doing the right things; leadership is doing the right things." -Peater Ducker'

# %%
for sent in doc.sents:
    print(sent)
    print('\n')
# Out:
# "Management is doing the right things; leadership is doing the right things."
#
#
# -Peater Ducker

# %% [markdown]
# ### Segmentation Rules :
# - add a segmentation rule
# - change segmentation rules

# %% [markdown]
# - 1) add a segmentation rule

# %%
def print_with_ind(doc):
    for token in doc:
        print(token, end = ' - ')
        print(token.i, end = ' | ')

# %%
print_with_ind(doc)
# Out:
# " - 0 | Management - 1 | is - 2 | doing - 3 | the - 4 | right - 5 | things - 6 | ; - 7 | leadership - 8 | is - 9 | doing - 10 | the - 11 | right - 12 | things - 13 | . - 14 | " - 15 | -Peater - 16 | Ducker - 17 |

# %%
# now we are going to add our custom method to the pipeline
# originally the pipeline consist of :
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
# selects unitl the second last string

doc[:-1]
# Out:
# "Management is doing the right things; leadership is doing the right things." -Peater

# %%
doc = nlp(u'"Management is doing the right things; leadership is doing the right things." -Peater Ducker')

# %%
for sent in doc.sents:
    print(sent)
# Out:
# "Management is doing the right things; leadership is doing the right things."
# -Peater Ducker

# %%
from spacy.language import Language

@Language.component("semicolonsent")
def set_custom_boundries(doc):
    print('im ex')
    for token in doc[:-1]:
        if token.text == ';':
            doc[token.i +1].is_sent_start = True
    return doc

# %%
doc[:-1]
# Out:
# "Management is doing the right things; leadership is doing the right things." -Peater

# %%
# CHANGE THE SEGMENTATION RULES

# %%
nlp.add_pipe("semicolonsent", name = "customname" ,before = 'parser')
# Out:
# <function __main__.set_custom_boundries(doc)>

# %%
nlp.pipe_names
# Out:
# ['tok2vec',
#  'tagger',
#  'customname',
#  'parser',
#  'attribute_ruler',
#  'lemmatizer',
#  'ner']

# %%
# remember you have to again define your string here, only then would it work(i mean the doc)
doc = nlp(u'"Management is doing the right things; leadership is doing the right things." -Peater Ducker')
for sent in doc.sents:
    print(sent)
list(doc.sents)
# Out:
# im ex
# "Management is doing the right things;
# leadership is doing the right things."
# -Peater Ducker
# ["Management is doing the right things;,
#  leadership is doing the right things.",
#  -Peater Ducker]

# %%
# CHANGE SEGMENTATION RULES

# %%
nlp = spacy.load('en_core_web_sm')

# %%
mystring = u"This is a sentence. This is another\n\nThis is a \nthird sentence."

# %%
print(mystring)
# Out:
# This is a sentence. This is another
#
# This is a
# third sentence.

# %%
type(mystring)
# Out:
# str

# %%
doc = nlp(mystring)

# %%
for sent in doc.sents:
    print(sent)
# Out:
# This is a sentence.
# This is another
#
# This is a
# third sentence.

# %%
from spacy.pipeline import SentenceSegmenter
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-219-538101332913> in <module>
# ----> 1 from spacy.pipeline import SentenceSegmenter
#
# ImportError: cannot import name 'SentenceSegmenter' from 'spacy.pipeline' (C:\Users\LENOVO\anaconda3\lib\site-packages\spacy\pipeline\__init__.py)

# %%
@Language.component("newrule_sentsplit")
def split_on_newlines(doc):
    start =0
    seen_newline = False
    
    for word in doc:
        if seen_newline:
            yield doc[start:word.i]
            start = word.i
            seen_newline = False
        elif word.text.startswith('\n'):
            seen_newline = True
    
    yield doc[start:]

# %%
sbd = Sentenceconfig = {"newrule_sentsplit": None}
nlp.add_pipe("sentencizer", config=config)
# Out:
# ---------------------------------------------------------------------------
# ConfigValidationError                     Traceback (most recent call last)
# <ipython-input-245-f841793cf4b8> in <module>
#       1 sbd = Sentenceconfig = {"newrule_sentsplit": None}
# ----> 2 nlp.add_pipe("sentencizer", config=sbd)
#
# ~\anaconda3\lib\site-packages\spacy\language.py in add_pipe(self, factory_name, name, before, after, first, last, source, config, raw_config, validate)
#     793                     lang_code=self.lang,
#     794                 )
# --> 795             pipe_component = self.create_pipe(
#     796                 factory_name,
#     797                 name=name,
#
# ~\anaconda3\lib\site-packages\spacy\language.py in create_pipe(self, factory_name, name, config, raw_config, validate)
#     672         # We're calling the internal _fill here to avoid constructing the
#     673         # registered functions twice
# --> 674         resolved = registry.resolve(cfg, validate=validate)
#     675         filled = registry.fill({"cfg": cfg[factory_name]}, validate=validate)["cfg"]
#     676         filled = Config(filled)
#
# ~\anaconda3\lib\site-packages\thinc\config.py in resolve(cls, config, schema, overrides, validate)
#     745         validate: bool = True,
#     746     ) -> Dict[str, Any]:
# --> 747         resolved, _ = cls._make(
#     748             config, schema=schema, overrides=overrides, validate=validate, resolve=True
#     749         )
#
# ~\anaconda3\lib\site-packages\thinc\config.py in _make(cls, config, schema, overrides, resolve, validate)
#     794         if not is_interpolated:
#     795             config = Config(orig_config).interpolate()
# --> 796         filled, _, resolved = cls._fill(
#     797             config, schema, validate=validate, overrides=overrides, resolve=resolve
#     798         )
#
# ~\anaconda3\lib\site-packages\thinc\config.py in _fill(cls, config, schema, validate, resolve, parent, overrides)
#     849                     schema.__fields__[key] = copy_model_field(field, Any)
#     850                 promise_schema = cls.make_promise_schema(value, resolve=resolve)
# --> 851                 filled[key], validation[v_key], final[key] = cls._fill(
#     852                     value,
#     853                     promise_schema,
#
# ~\anaconda3\lib\site-packages\thinc\config.py in _fill(cls, config, schema, validate, resolve, parent, overrides)
#     915                 result = schema.parse_obj(validation)
#     916             except ValidationError as e:
# --> 917                 raise ConfigValidationError(
#     918                     config=config, errors=e.errors(), parent=parent
#     919                 ) from None
#
# ConfigValidationError:
#
# Config validation error
#
# sentencizer -> newrule_sentsplit   extra fields not permitted
#
# {'nlp': <spacy.lang.en.English object at 0x000001DB44AEC4F0>, 'name': 'sentencizer', 'newrule_sentsplit': None, 'overwrite': False, 'punct_chars': None, 'scorer': {'@scorers': 'spacy.senter_scorer.v1'}, '@factories': 'sentencizer'}

# %% [markdown]
# # NOT COMPLEATED DO IT AGAIN

# %% [markdown]
# # Assesment

# %%
# create doc obj from file petrrabit.txt

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')
from spacy import displacy

# %%
myfile = open('resources/peterrabbit.txt', 'r')

# %%
# for every token in the third sentence print the token text, the POS tag, the fine-grained tag...

# %%
doc = nlp(myfile.read())

# %%
for token in doc:
    print(f'{token.text:{10}} {token.pos_:{10}} {token.tag_:{10}}  {spacy.explain(token.tag_):{10}}')
# Out:
# The        DET        DT          determiner
# Tale       PROPN      NNP         noun, proper singular
# of         ADP        IN          conjunction, subordinating or preposition
# Peter      PROPN      NNP         noun, proper singular
# Rabbit     PROPN      NNP         noun, proper singular
# ,          PUNCT      ,           punctuation mark, comma
# by         ADP        IN          conjunction, subordinating or preposition
# Beatrix    PROPN      NNP         noun, proper singular
# Potter     PROPN      NNP         noun, proper singular
# (          PUNCT      -LRB-       left round bracket
# 1902       NUM        CD          cardinal number
# )          PUNCT      -RRB-       right round bracket
# .          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# Once       ADV        RB          adverb
# upon       SCONJ      IN          conjunction, subordinating or preposition
# a          DET        DT          determiner
# time       NOUN       NN          noun, singular or mass
# there      PRON       EX          existential there
# were       VERB       VBD         verb, past tense
# four       NUM        CD          cardinal number
# little     ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# Rabbits    NOUN       NNS         noun, plural
# ,          PUNCT      ,           punctuation mark, comma
# and        CCONJ      CC          conjunction, coordinating
# their      PRON       PRP$        pronoun, possessive
# names      NOUN       NNS         noun, plural
#
#           SPACE      _SP         whitespace
# were--     PROPN      NNP         noun, proper singular
#
#
#            SPACE      _SP         whitespace
# Flopsy     PROPN      NNP         noun, proper singular
# ,          PUNCT      ,           punctuation mark, comma
#
#           SPACE      _SP         whitespace
# Mopsy      PROPN      NNP         noun, proper singular
# ,          PUNCT      ,           punctuation mark, comma
#
#           SPACE      _SP         whitespace
# Cotton     PROPN      NNP         noun, proper singular
# -          PUNCT      HYPH        punctuation mark, hyphen
# tail       NOUN       NN          noun, singular or mass
# ,          PUNCT      ,           punctuation mark, comma
#
#           SPACE      _SP         whitespace
# and        CCONJ      CC          conjunction, coordinating
# Peter      PROPN      NNP         noun, proper singular
# .          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# They       PRON       PRP         pronoun, personal
# lived      VERB       VBD         verb, past tense
# with       ADP        IN          conjunction, subordinating or preposition
# their      PRON       PRP$        pronoun, possessive
# Mother     PROPN      NNP         noun, proper singular
# in         ADP        IN          conjunction, subordinating or preposition
# a          DET        DT          determiner
# sand       NOUN       NN          noun, singular or mass
# -          PUNCT      HYPH        punctuation mark, hyphen
# bank       NOUN       NN          noun, singular or mass
# ,          PUNCT      ,           punctuation mark, comma
# underneath ADP        IN          conjunction, subordinating or preposition
# the        DET        DT          determiner
# root       NOUN       NN          noun, singular or mass
# of         ADP        IN          conjunction, subordinating or preposition
# a          DET        DT          determiner
#
#           SPACE      _SP         whitespace
# very       ADV        RB          adverb
# big        ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# fir        NOUN       NN          noun, singular or mass
# -          PUNCT      HYPH        punctuation mark, hyphen
# tree       NOUN       NN          noun, singular or mass
# .          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# '          PUNCT      ''          closing quotation mark
# Now        ADV        RB          adverb
# my         PRON       PRP$        pronoun, possessive
# dears      NOUN       NNS         noun, plural
# ,          PUNCT      ,           punctuation mark, comma
# '          PUNCT      ''          closing quotation mark
# said       VERB       VBD         verb, past tense
# old        ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# Mrs.       PROPN      NNP         noun, proper singular
# Rabbit     PROPN      NNP         noun, proper singular
# one        NUM        CD          cardinal number
# morning    NOUN       NN          noun, singular or mass
# ,          PUNCT      ,           punctuation mark, comma
# '          PUNCT      ``          opening quotation mark
# you        PRON       PRP         pronoun, personal
# may        AUX        MD          verb, modal auxiliary
# go         VERB       VB          verb, base form
# into       ADP        IN          conjunction, subordinating or preposition
#
#           SPACE      _SP         whitespace
# the        DET        DT          determiner
# fields     NOUN       NNS         noun, plural
# or         CCONJ      CC          conjunction, coordinating
# down       ADP        IN          conjunction, subordinating or preposition
# the        DET        DT          determiner
# lane       NOUN       NN          noun, singular or mass
# ,          PUNCT      ,           punctuation mark, comma
# but        CCONJ      CC          conjunction, coordinating
# do         AUX        VBP         verb, non-3rd person singular present
# n't        PART       RB          adverb
# go         VERB       VB          verb, base form
# into       ADP        IN          conjunction, subordinating or preposition
# Mr.        PROPN      NNP         noun, proper singular
# McGregor   PROPN      NNP         noun, proper singular
# 's         PART       POS         possessive ending
# garden     NOUN       NN          noun, singular or mass
# :          PUNCT      :           punctuation mark, colon or ellipsis
#
#           SPACE      _SP         whitespace
# your       PRON       PRP$        pronoun, possessive
# Father     PROPN      NNP         noun, proper singular
# had        VERB       VBD         verb, past tense
# an         DET        DT          determiner
# accident   NOUN       NN          noun, singular or mass
# there      ADV        RB          adverb
# ;          PUNCT      :           punctuation mark, colon or ellipsis
# he         PRON       PRP         pronoun, personal
# was        AUX        VBD         verb, past tense
# put        VERB       VBN         verb, past participle
# in         ADP        IN          conjunction, subordinating or preposition
# a          DET        DT          determiner
# pie        NOUN       NN          noun, singular or mass
# by         ADP        IN          conjunction, subordinating or preposition
# Mrs.       PROPN      NNP         noun, proper singular
#
#           SPACE      _SP         whitespace
# McGregor   PROPN      NNP         noun, proper singular
# .          PUNCT      .           punctuation mark, sentence closer
# '          PUNCT      ''          closing quotation mark
#
#
#          SPACE      _SP         whitespace
# '          PUNCT      ''          closing quotation mark
# Now        ADV        RB          adverb
# run        VERB       VB          verb, base form
# along      ADV        RB          adverb
# ,          PUNCT      ,           punctuation mark, comma
# and        CCONJ      CC          conjunction, coordinating
# do         AUX        VBP         verb, non-3rd person singular present
# n't        PART       RB          adverb
# get        VERB       VB          verb, base form
# into       ADP        IN          conjunction, subordinating or preposition
# mischief   NOUN       NN          noun, singular or mass
# .          PUNCT      .           punctuation mark, sentence closer
# I          PRON       PRP         pronoun, personal
# am         AUX        VBP         verb, non-3rd person singular present
# going      VERB       VBG         verb, gerund or present participle
# out        ADP        RP          adverb, particle
# .          PUNCT      .           punctuation mark, sentence closer
# '          PUNCT      ''          closing quotation mark
#
#
#          SPACE      _SP         whitespace
# Then       ADV        RB          adverb
# old        ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# Mrs.       PROPN      NNP         noun, proper singular
# Rabbit     PROPN      NNP         noun, proper singular
# took       VERB       VBD         verb, past tense
# a          DET        DT          determiner
# basket     NOUN       NN          noun, singular or mass
# and        CCONJ      CC          conjunction, coordinating
# her        PRON       PRP$        pronoun, possessive
# umbrella   NOUN       NN          noun, singular or mass
# ,          PUNCT      ,           punctuation mark, comma
# and        CCONJ      CC          conjunction, coordinating
# went       VERB       VBD         verb, past tense
# through    ADP        IN          conjunction, subordinating or preposition
#
#           SPACE      _SP         whitespace
# the        DET        DT          determiner
# wood       NOUN       NN          noun, singular or mass
# to         ADP        IN          conjunction, subordinating or preposition
# the        DET        DT          determiner
# baker      PROPN      NNP         noun, proper singular
# 's         PART       POS         possessive ending
# .          PUNCT      .           punctuation mark, sentence closer
# She        PRON       PRP         pronoun, personal
# bought     VERB       VBD         verb, past tense
# a          DET        DT          determiner
# loaf       NOUN       NN          noun, singular or mass
# of         ADP        IN          conjunction, subordinating or preposition
# brown      ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# bread      NOUN       NN          noun, singular or mass
# and        CCONJ      CC          conjunction, coordinating
# five       NUM        CD          cardinal number
#
#           SPACE      _SP         whitespace
# currant    ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# buns       NOUN       NNS         noun, plural
# .          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# Flopsy     PROPN      NNP         noun, proper singular
# ,          PUNCT      ,           punctuation mark, comma
# Mopsy      PROPN      NNP         noun, proper singular
# ,          PUNCT      ,           punctuation mark, comma
# and        CCONJ      CC          conjunction, coordinating
# Cottontail PROPN      NNP         noun, proper singular
# ,          PUNCT      ,           punctuation mark, comma
# who        PRON       WP          wh-pronoun, personal
# were       AUX        VBD         verb, past tense
# good       ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# little     ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# bunnies    NOUN       NNS         noun, plural
# ,          PUNCT      ,           punctuation mark, comma
# went       VERB       VBD         verb, past tense
#
#           SPACE      _SP         whitespace
# down       ADP        IN          conjunction, subordinating or preposition
# the        DET        DT          determiner
# lane       NOUN       NN          noun, singular or mass
# to         PART       TO          infinitival "to"
# gather     VERB       VB          verb, base form
# blackberries NOUN       NNS         noun, plural
# :          PUNCT      :           punctuation mark, colon or ellipsis
#
#
#          SPACE      _SP         whitespace
# But        CCONJ      CC          conjunction, coordinating
# Peter      PROPN      NNP         noun, proper singular
# ,          PUNCT      ,           punctuation mark, comma
# who        PRON       WP          wh-pronoun, personal
# was        AUX        VBD         verb, past tense
# very       ADV        RB          adverb
# naughty    ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# ,          PUNCT      ,           punctuation mark, comma
# ran        VERB       VBD         verb, past tense
# straight   ADV        RB          adverb
# away       ADV        RB          adverb
# to         ADP        IN          conjunction, subordinating or preposition
# Mr.        PROPN      NNP         noun, proper singular
# McGregor   PROPN      NNP         noun, proper singular
# 's         PART       POS         possessive ending
#
#           SPACE      _SP         whitespace
# garden     NOUN       NN          noun, singular or mass
# ,          PUNCT      ,           punctuation mark, comma
# and        CCONJ      CC          conjunction, coordinating
# squeezed   VERB       VBN         verb, past participle
# under      ADP        IN          conjunction, subordinating or preposition
# the        DET        DT          determiner
# gate       NOUN       NN          noun, singular or mass
# !          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# First      ADV        RB          adverb
# he         PRON       PRP         pronoun, personal
# ate        VERB       VBD         verb, past tense
# some       DET        DT          determiner
# lettuces   NOUN       NNS         noun, plural
# and        CCONJ      CC          conjunction, coordinating
# some       DET        DT          determiner
# French     ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# beans      NOUN       NNS         noun, plural
# ;          PUNCT      :           punctuation mark, colon or ellipsis
# and        CCONJ      CC          conjunction, coordinating
# then       ADV        RB          adverb
# he         PRON       PRP         pronoun, personal
# ate        VERB       VBD         verb, past tense
#
#           SPACE      _SP         whitespace
# some       DET        DT          determiner
# radishes   NOUN       NNS         noun, plural
# ;          PUNCT      :           punctuation mark, colon or ellipsis
#
#
#          SPACE      _SP         whitespace
# And        CCONJ      CC          conjunction, coordinating
# then       ADV        RB          adverb
# ,          PUNCT      ,           punctuation mark, comma
# feeling    VERB       VBG         verb, gerund or present participle
# rather     ADV        RB          adverb
# sick       ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# ,          PUNCT      ,           punctuation mark, comma
# he         PRON       PRP         pronoun, personal
# went       VERB       VBD         verb, past tense
# to         PART       TO          infinitival "to"
# look       VERB       VB          verb, base form
# for        ADP        IN          conjunction, subordinating or preposition
# some       DET        DT          determiner
# parsley    NOUN       NN          noun, singular or mass
# .          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# But        CCONJ      CC          conjunction, coordinating
# round      VERB       VB          verb, base form
# the        DET        DT          determiner
# end        NOUN       NN          noun, singular or mass
# of         ADP        IN          conjunction, subordinating or preposition
# a          DET        DT          determiner
# cucumber   ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# frame      NOUN       NN          noun, singular or mass
# ,          PUNCT      ,           punctuation mark, comma
# whom       PRON       WP          wh-pronoun, personal
# should     AUX        MD          verb, modal auxiliary
# he         PRON       PRP         pronoun, personal
# meet       VERB       VB          verb, base form
# but        CCONJ      CC          conjunction, coordinating
# Mr.        PROPN      NNP         noun, proper singular
#
#           SPACE      _SP         whitespace
# McGregor   PROPN      NNP         noun, proper singular
# !          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# Mr.        PROPN      NNP         noun, proper singular
# McGregor   PROPN      NNP         noun, proper singular
# was        AUX        VBD         verb, past tense
# on         ADP        IN          conjunction, subordinating or preposition
# his        PRON       PRP$        pronoun, possessive
# hands      NOUN       NNS         noun, plural
# and        CCONJ      CC          conjunction, coordinating
# knees      NOUN       NNS         noun, plural
# planting   VERB       VBG         verb, gerund or present participle
# out        ADP        RP          adverb, particle
# young      ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# cabbages   NOUN       NNS         noun, plural
# ,          PUNCT      ,           punctuation mark, comma
#
#           SPACE      _SP         whitespace
# but        CCONJ      CC          conjunction, coordinating
# he         PRON       PRP         pronoun, personal
# jumped     VERB       VBD         verb, past tense
# up         ADP        RP          adverb, particle
# and        CCONJ      CC          conjunction, coordinating
# ran        VERB       VBD         verb, past tense
# after      ADP        IN          conjunction, subordinating or preposition
# Peter      PROPN      NNP         noun, proper singular
# ,          PUNCT      ,           punctuation mark, comma
# waving     VERB       VBG         verb, gerund or present participle
# a          DET        DT          determiner
# rake       NOUN       NN          noun, singular or mass
# and        CCONJ      CC          conjunction, coordinating
# calling    VERB       VBG         verb, gerund or present participle
# out        ADP        RP          adverb, particle
# ,          PUNCT      ,           punctuation mark, comma
#
#           SPACE      _SP         whitespace
# '          PUNCT      ``          opening quotation mark
# Stop       VERB       VB          verb, base form
# thief      NOUN       NN          noun, singular or mass
# !          PUNCT      .           punctuation mark, sentence closer
# '          PUNCT      ''          closing quotation mark
#
#
#          SPACE      _SP         whitespace
# Peter      PROPN      NNP         noun, proper singular
# was        AUX        VBD         verb, past tense
# most       ADV        RBS         adverb, superlative
# dreadfully ADV        RB          adverb
# frightened ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# ;          PUNCT      :           punctuation mark, colon or ellipsis
# he         PRON       PRP         pronoun, personal
# rushed     VERB       VBD         verb, past tense
# all        ADV        RB          adverb
# over       ADP        IN          conjunction, subordinating or preposition
# the        DET        DT          determiner
# garden     NOUN       NN          noun, singular or mass
# ,          PUNCT      ,           punctuation mark, comma
#
#           SPACE      _SP         whitespace
# for        SCONJ      IN          conjunction, subordinating or preposition
# he         PRON       PRP         pronoun, personal
# had        AUX        VBD         verb, past tense
# forgotten  VERB       VBN         verb, past participle
# the        DET        DT          determiner
# way        NOUN       NN          noun, singular or mass
# back       ADV        RB          adverb
# to         ADP        IN          conjunction, subordinating or preposition
# the        DET        DT          determiner
# gate       NOUN       NN          noun, singular or mass
# .          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# He         PRON       PRP         pronoun, personal
# lost       VERB       VBD         verb, past tense
# one        NUM        CD          cardinal number
# of         ADP        IN          conjunction, subordinating or preposition
# his        PRON       PRP$        pronoun, possessive
# shoes      NOUN       NNS         noun, plural
# among      ADP        IN          conjunction, subordinating or preposition
# the        DET        DT          determiner
# cabbages   NOUN       NNS         noun, plural
# ,          PUNCT      ,           punctuation mark, comma
# and        CCONJ      CC          conjunction, coordinating
# the        DET        DT          determiner
# other      ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# shoe       NOUN       NN          noun, singular or mass
#
#           SPACE      _SP         whitespace
# amongst    ADP        IN          conjunction, subordinating or preposition
# the        DET        DT          determiner
# potatoes   NOUN       NNS         noun, plural
# .          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# After      ADP        IN          conjunction, subordinating or preposition
# losing     VERB       VBG         verb, gerund or present participle
# them       PRON       PRP         pronoun, personal
# ,          PUNCT      ,           punctuation mark, comma
# he         PRON       PRP         pronoun, personal
# ran        VERB       VBD         verb, past tense
# on         ADP        IN          conjunction, subordinating or preposition
# four       NUM        CD          cardinal number
# legs       NOUN       NNS         noun, plural
# and        CCONJ      CC          conjunction, coordinating
# went       VERB       VBD         verb, past tense
# faster     ADV        RBR         adverb, comparative
# ,          PUNCT      ,           punctuation mark, comma
# so         SCONJ      IN          conjunction, subordinating or preposition
# that       SCONJ      IN          conjunction, subordinating or preposition
# I          PRON       PRP         pronoun, personal
#
#           SPACE      _SP         whitespace
# think      VERB       VBP         verb, non-3rd person singular present
# he         PRON       PRP         pronoun, personal
# might      AUX        MD          verb, modal auxiliary
# have       AUX        VB          verb, base form
# got        VERB       VBN         verb, past participle
# away       ADV        RB          adverb
# altogether ADV        RB          adverb
# if         SCONJ      IN          conjunction, subordinating or preposition
# he         PRON       PRP         pronoun, personal
# had        AUX        VBD         verb, past tense
# not        PART       RB          adverb
# unfortunately ADV        RB          adverb
#
#           SPACE      _SP         whitespace
# run        VERB       VBN         verb, past participle
# into       ADP        IN          conjunction, subordinating or preposition
# a          DET        DT          determiner
# gooseberry NOUN       NN          noun, singular or mass
# net        NOUN       NN          noun, singular or mass
# ,          PUNCT      ,           punctuation mark, comma
# and        CCONJ      CC          conjunction, coordinating
# got        AUX        VBD         verb, past tense
# caught     VERB       VBN         verb, past participle
# by         ADP        IN          conjunction, subordinating or preposition
# the        DET        DT          determiner
# large      ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# buttons    NOUN       NNS         noun, plural
# on         ADP        IN          conjunction, subordinating or preposition
# his        PRON       PRP$        pronoun, possessive
#
#           SPACE      _SP         whitespace
# jacket     NOUN       NN          noun, singular or mass
# .          PUNCT      .           punctuation mark, sentence closer
# It         PRON       PRP         pronoun, personal
# was        AUX        VBD         verb, past tense
# a          DET        DT          determiner
# blue       ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# jacket     NOUN       NN          noun, singular or mass
# with       ADP        IN          conjunction, subordinating or preposition
# brass      NOUN       NN          noun, singular or mass
# buttons    NOUN       NNS         noun, plural
# ,          PUNCT      ,           punctuation mark, comma
# quite      ADV        RB          adverb
# new        ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# .          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# Peter      PROPN      NNP         noun, proper singular
# gave       VERB       VBD         verb, past tense
# himself    PRON       PRP         pronoun, personal
# up         ADP        RP          adverb, particle
# for        ADP        IN          conjunction, subordinating or preposition
# lost       ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# ,          PUNCT      ,           punctuation mark, comma
# and        CCONJ      CC          conjunction, coordinating
# shed       VERB       VB          verb, base form
# big        ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# tears      NOUN       NNS         noun, plural
# ;          PUNCT      :           punctuation mark, colon or ellipsis
# but        CCONJ      CC          conjunction, coordinating
# his        PRON       PRP$        pronoun, possessive
# sobs       NOUN       NN          noun, singular or mass
# were       AUX        VBD         verb, past tense
#
#           SPACE      _SP         whitespace
# overheard  VERB       VBN         verb, past participle
# by         ADP        IN          conjunction, subordinating or preposition
# some       DET        DT          determiner
# friendly   ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# sparrows   NOUN       NNS         noun, plural
# ,          PUNCT      ,           punctuation mark, comma
# who        PRON       WP          wh-pronoun, personal
# flew       VERB       VBD         verb, past tense
# to         ADP        IN          conjunction, subordinating or preposition
# him        PRON       PRP         pronoun, personal
# in         ADP        IN          conjunction, subordinating or preposition
# great      ADJ        JJ          adjective (English), other noun-modifier (Chinese)
#
#           SPACE      _SP         whitespace
# excitement NOUN       NN          noun, singular or mass
# ,          PUNCT      ,           punctuation mark, comma
# and        CCONJ      CC          conjunction, coordinating
# implored   VERB       VBD         verb, past tense
# him        PRON       PRP         pronoun, personal
# to         PART       TO          infinitival "to"
# exert      VERB       VB          verb, base form
# himself    PRON       PRP         pronoun, personal
# .          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# Mr.        PROPN      NNP         noun, proper singular
# McGregor   PROPN      NNP         noun, proper singular
# came       VERB       VBD         verb, past tense
# up         ADP        RP          adverb, particle
# with       ADP        IN          conjunction, subordinating or preposition
# a          DET        DT          determiner
# sieve      NOUN       NN          noun, singular or mass
# ,          PUNCT      ,           punctuation mark, comma
# which      PRON       WDT         wh-determiner
# he         PRON       PRP         pronoun, personal
# intended   VERB       VBD         verb, past tense
# to         PART       TO          infinitival "to"
# pop        VERB       VB          verb, base form
# upon       SCONJ      IN          conjunction, subordinating or preposition
# the        DET        DT          determiner
#
#           SPACE      _SP         whitespace
# top        NOUN       NN          noun, singular or mass
# of         ADP        IN          conjunction, subordinating or preposition
# Peter      PROPN      NNP         noun, proper singular
# ;          PUNCT      :           punctuation mark, colon or ellipsis
# but        CCONJ      CC          conjunction, coordinating
# Peter      PROPN      NNP         noun, proper singular
# wriggled   VERB       VBD         verb, past tense
# out        ADP        RP          adverb, particle
# just       ADV        RB          adverb
# in         ADP        IN          conjunction, subordinating or preposition
# time       NOUN       NN          noun, singular or mass
# ,          PUNCT      ,           punctuation mark, comma
# leaving    VERB       VBG         verb, gerund or present participle
# his        PRON       PRP$        pronoun, possessive
# jacket     NOUN       NN          noun, singular or mass
#
#           SPACE      _SP         whitespace
# behind     ADP        IN          conjunction, subordinating or preposition
# him        PRON       PRP         pronoun, personal
# .          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# And        CCONJ      CC          conjunction, coordinating
# rushed     VERB       VBD         verb, past tense
# into       ADP        IN          conjunction, subordinating or preposition
# the        DET        DT          determiner
# tool       NOUN       NN          noun, singular or mass
# -          PUNCT      HYPH        punctuation mark, hyphen
# shed       VERB       VBN         verb, past participle
# ,          PUNCT      ,           punctuation mark, comma
# and        CCONJ      CC          conjunction, coordinating
# jumped     VERB       VBD         verb, past tense
# into       ADP        IN          conjunction, subordinating or preposition
# a          DET        DT          determiner
# can        NOUN       NN          noun, singular or mass
# .          PUNCT      .           punctuation mark, sentence closer
# It         PRON       PRP         pronoun, personal
# would      AUX        MD          verb, modal auxiliary
# have       AUX        VB          verb, base form
#
#           SPACE      _SP         whitespace
# been       AUX        VBN         verb, past participle
# a          DET        DT          determiner
# beautiful  ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# thing      NOUN       NN          noun, singular or mass
# to         PART       TO          infinitival "to"
# hide       VERB       VB          verb, base form
# in         ADV        RB          adverb
# ,          PUNCT      ,           punctuation mark, comma
# if         SCONJ      IN          conjunction, subordinating or preposition
# it         PRON       PRP         pronoun, personal
# had        AUX        VBD         verb, past tense
# not        PART       RB          adverb
# had        VERB       VBN         verb, past participle
# so         ADV        RB          adverb
# much       ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# water      NOUN       NN          noun, singular or mass
# in         ADP        IN          conjunction, subordinating or preposition
# it         PRON       PRP         pronoun, personal
# .          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# Mr.        PROPN      NNP         noun, proper singular
# McGregor   PROPN      NNP         noun, proper singular
# was        AUX        VBD         verb, past tense
# quite      ADV        RB          adverb
# sure       ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# that       SCONJ      IN          conjunction, subordinating or preposition
# Peter      PROPN      NNP         noun, proper singular
# was        AUX        VBD         verb, past tense
# somewhere  ADV        RB          adverb
# in         ADP        IN          conjunction, subordinating or preposition
# the        DET        DT          determiner
#
#           SPACE      _SP         whitespace
# tool       NOUN       NN          noun, singular or mass
# -          PUNCT      HYPH        punctuation mark, hyphen
# shed       VERB       VBN         verb, past participle
# ,          PUNCT      ,           punctuation mark, comma
# perhaps    ADV        RB          adverb
# hidden     VERB       VBN         verb, past participle
# underneath ADP        IN          conjunction, subordinating or preposition
# a          DET        DT          determiner
# flower     NOUN       NN          noun, singular or mass
# -          PUNCT      HYPH        punctuation mark, hyphen
# pot        NOUN       NN          noun, singular or mass
# .          PUNCT      .           punctuation mark, sentence closer
# He         PRON       PRP         pronoun, personal
# began      VERB       VBD         verb, past tense
# to         PART       TO          infinitival "to"
# turn       VERB       VB          verb, base form
#
#           SPACE      _SP         whitespace
# them       PRON       PRP         pronoun, personal
# over       ADV        RB          adverb
# carefully  ADV        RB          adverb
# ,          PUNCT      ,           punctuation mark, comma
# looking    VERB       VBG         verb, gerund or present participle
# under      ADP        IN          conjunction, subordinating or preposition
# each       PRON       DT          determiner
# .          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# Presently  ADV        RB          adverb
# Peter      PROPN      NNP         noun, proper singular
# sneezed--'Kertyschoo PROPN      NNP         noun, proper singular
# !          PUNCT      .           punctuation mark, sentence closer
# '          PUNCT      ''          closing quotation mark
# Mr.        PROPN      NNP         noun, proper singular
# McGregor   PROPN      NNP         noun, proper singular
# was        AUX        VBD         verb, past tense
# after      ADP        IN          conjunction, subordinating or preposition
# him        PRON       PRP         pronoun, personal
# in         ADP        IN          conjunction, subordinating or preposition
#
#           SPACE      _SP         whitespace
# no         DET        DT          determiner
# time       NOUN       NN          noun, singular or mass
# .          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# And        CCONJ      CC          conjunction, coordinating
# tried      VERB       VBD         verb, past tense
# to         PART       TO          infinitival "to"
# put        VERB       VB          verb, base form
# his        PRON       PRP$        pronoun, possessive
# foot       NOUN       NN          noun, singular or mass
# upon       SCONJ      IN          conjunction, subordinating or preposition
# Peter      PROPN      NNP         noun, proper singular
# ,          PUNCT      ,           punctuation mark, comma
# who        PRON       WP          wh-pronoun, personal
# jumped     VERB       VBD         verb, past tense
# out        ADP        IN          conjunction, subordinating or preposition
# of         ADP        IN          conjunction, subordinating or preposition
# a          DET        DT          determiner
# window     NOUN       NN          noun, singular or mass
# ,          PUNCT      ,           punctuation mark, comma
#
#           SPACE      _SP         whitespace
# upsetting  VERB       VBG         verb, gerund or present participle
# three      NUM        CD          cardinal number
# plants     NOUN       NNS         noun, plural
# .          PUNCT      .           punctuation mark, sentence closer
# The        DET        DT          determiner
# window     NOUN       NN          noun, singular or mass
# was        AUX        VBD         verb, past tense
# too        ADV        RB          adverb
# small      ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# for        ADP        IN          conjunction, subordinating or preposition
# Mr.        PROPN      NNP         noun, proper singular
# McGregor   PROPN      NNP         noun, proper singular
# ,          PUNCT      ,           punctuation mark, comma
# and        CCONJ      CC          conjunction, coordinating
#
#           SPACE      _SP         whitespace
# he         PRON       PRP         pronoun, personal
# was        AUX        VBD         verb, past tense
# tired      ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# of         ADP        IN          conjunction, subordinating or preposition
# running    VERB       VBG         verb, gerund or present participle
# after      ADP        IN          conjunction, subordinating or preposition
# Peter      PROPN      NNP         noun, proper singular
# .          PUNCT      .           punctuation mark, sentence closer
# He         PRON       PRP         pronoun, personal
# went       VERB       VBD         verb, past tense
# back       ADV        RB          adverb
# to         ADP        IN          conjunction, subordinating or preposition
# his        PRON       PRP$        pronoun, possessive
# work       NOUN       NN          noun, singular or mass
# .          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# Peter      PROPN      NNP         noun, proper singular
# sat        VERB       VBD         verb, past tense
# down       ADP        RP          adverb, particle
# to         ADP        IN          conjunction, subordinating or preposition
# rest       VERB       VB          verb, base form
# ;          PUNCT      :           punctuation mark, colon or ellipsis
# he         PRON       PRP         pronoun, personal
# was        AUX        VBD         verb, past tense
# out        ADP        IN          conjunction, subordinating or preposition
# of         ADP        IN          conjunction, subordinating or preposition
# breath     NOUN       NN          noun, singular or mass
# and        CCONJ      CC          conjunction, coordinating
# trembling  VERB       VBG         verb, gerund or present participle
# with       ADP        IN          conjunction, subordinating or preposition
#
#           SPACE      _SP         whitespace
# fright     NOUN       NN          noun, singular or mass
# ,          PUNCT      ,           punctuation mark, comma
# and        CCONJ      CC          conjunction, coordinating
# he         PRON       PRP         pronoun, personal
# had        VERB       VBD         verb, past tense
# not        PART       RB          adverb
# the        DET        DT          determiner
# least      ADJ        JJS         adjective, superlative
# idea       NOUN       NN          noun, singular or mass
# which      DET        WDT         wh-determiner
# way        NOUN       NN          noun, singular or mass
# to         PART       TO          infinitival "to"
# go         VERB       VB          verb, base form
# .          PUNCT      .           punctuation mark, sentence closer
# Also       ADV        RB          adverb
# he         PRON       PRP         pronoun, personal
# was        AUX        VBD         verb, past tense
#
#           SPACE      _SP         whitespace
# very       ADV        RB          adverb
# damp       ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# with       ADP        IN          conjunction, subordinating or preposition
# sitting    VERB       VBG         verb, gerund or present participle
# in         ADP        IN          conjunction, subordinating or preposition
# that       DET        DT          determiner
# can        AUX        MD          verb, modal auxiliary
# .          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# After      ADP        IN          conjunction, subordinating or preposition
# a          DET        DT          determiner
# time       NOUN       NN          noun, singular or mass
# he         PRON       PRP         pronoun, personal
# began      VERB       VBD         verb, past tense
# to         PART       TO          infinitival "to"
# wander     VERB       VB          verb, base form
# about      ADP        IN          conjunction, subordinating or preposition
# ,          PUNCT      ,           punctuation mark, comma
# going      VERB       VBG         verb, gerund or present participle
# lippity    NOUN       NN          noun, singular or mass
# --         PUNCT      :           punctuation mark, colon or ellipsis
# lippity    NOUN       NN          noun, singular or mass
# --         PUNCT      :           punctuation mark, colon or ellipsis
# not        PART       RB          adverb
#
#           SPACE      _SP         whitespace
# very       ADV        RB          adverb
# fast       ADV        RB          adverb
# ,          PUNCT      ,           punctuation mark, comma
# and        CCONJ      CC          conjunction, coordinating
# looking    VERB       VBG         verb, gerund or present participle
# all        PRON       DT          determiner
# round      ADV        RB          adverb
# .          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# He         PRON       PRP         pronoun, personal
# found      VERB       VBD         verb, past tense
# a          DET        DT          determiner
# door       NOUN       NN          noun, singular or mass
# in         ADP        IN          conjunction, subordinating or preposition
# a          DET        DT          determiner
# wall       NOUN       NN          noun, singular or mass
# ;          PUNCT      :           punctuation mark, colon or ellipsis
# but        CCONJ      CC          conjunction, coordinating
# it         PRON       PRP         pronoun, personal
# was        AUX        VBD         verb, past tense
# locked     VERB       VBN         verb, past participle
# ,          PUNCT      ,           punctuation mark, comma
# and        CCONJ      CC          conjunction, coordinating
# there      PRON       EX          existential there
# was        VERB       VBD         verb, past tense
# no         DET        DT          determiner
# room       NOUN       NN          noun, singular or mass
#
#           SPACE      _SP         whitespace
# for        ADP        IN          conjunction, subordinating or preposition
# a          DET        DT          determiner
# fat        ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# little     ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# rabbit     NOUN       NN          noun, singular or mass
# to         PART       TO          infinitival "to"
# squeeze    VERB       VB          verb, base form
# underneath ADV        RB          adverb
# .          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# An         DET        DT          determiner
# old        ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# mouse      NOUN       NN          noun, singular or mass
# was        AUX        VBD         verb, past tense
# running    VERB       VBG         verb, gerund or present participle
# in         ADP        IN          conjunction, subordinating or preposition
# and        CCONJ      CC          conjunction, coordinating
# out        ADV        RB          adverb
# over       ADP        IN          conjunction, subordinating or preposition
# the        DET        DT          determiner
# stone      NOUN       NN          noun, singular or mass
# doorstep   NOUN       NN          noun, singular or mass
# ,          PUNCT      ,           punctuation mark, comma
# carrying   VERB       VBG         verb, gerund or present participle
#
#           SPACE      _SP         whitespace
# peas       NOUN       NNS         noun, plural
# and        CCONJ      CC          conjunction, coordinating
# beans      NOUN       NNS         noun, plural
# to         ADP        IN          conjunction, subordinating or preposition
# her        PRON       PRP$        pronoun, possessive
# family     NOUN       NN          noun, singular or mass
# in         ADP        IN          conjunction, subordinating or preposition
# the        DET        DT          determiner
# wood       NOUN       NN          noun, singular or mass
# .          PUNCT      .           punctuation mark, sentence closer
# Peter      PROPN      NNP         noun, proper singular
# asked      VERB       VBD         verb, past tense
# her        PRON       PRP         pronoun, personal
# the        DET        DT          determiner
# way        NOUN       NN          noun, singular or mass
# to         ADP        IN          conjunction, subordinating or preposition
#
#           SPACE      _SP         whitespace
# the        DET        DT          determiner
# gate       NOUN       NN          noun, singular or mass
# ,          PUNCT      ,           punctuation mark, comma
# but        CCONJ      CC          conjunction, coordinating
# she        PRON       PRP         pronoun, personal
# had        VERB       VBD         verb, past tense
# such       DET        PDT         predeterminer
# a          DET        DT          determiner
# large      ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# pea        NOUN       NN          noun, singular or mass
# in         ADP        IN          conjunction, subordinating or preposition
# her        PRON       PRP$        pronoun, possessive
# mouth      NOUN       NN          noun, singular or mass
# that       SCONJ      IN          conjunction, subordinating or preposition
# she        PRON       PRP         pronoun, personal
# could      AUX        MD          verb, modal auxiliary
# not        PART       RB          adverb
#
#           SPACE      _SP         whitespace
# answer     VERB       VB          verb, base form
# .          PUNCT      .           punctuation mark, sentence closer
# She        PRON       PRP         pronoun, personal
# only       ADV        RB          adverb
# shook      VERB       VBD         verb, past tense
# her        PRON       PRP$        pronoun, possessive
# head       NOUN       NN          noun, singular or mass
# at         ADP        IN          conjunction, subordinating or preposition
# him        PRON       PRP         pronoun, personal
# .          PUNCT      .           punctuation mark, sentence closer
# Peter      PROPN      NNP         noun, proper singular
# began      VERB       VBD         verb, past tense
# to         PART       TO          infinitival "to"
# cry        VERB       VB          verb, base form
# .          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# Then       ADV        RB          adverb
# he         PRON       PRP         pronoun, personal
# tried      VERB       VBD         verb, past tense
# to         PART       TO          infinitival "to"
# find       VERB       VB          verb, base form
# his        PRON       PRP$        pronoun, possessive
# way        NOUN       NN          noun, singular or mass
# straight   ADV        RB          adverb
# across     ADP        IN          conjunction, subordinating or preposition
# the        DET        DT          determiner
# garden     NOUN       NN          noun, singular or mass
# ,          PUNCT      ,           punctuation mark, comma
# but        CCONJ      CC          conjunction, coordinating
# he         PRON       PRP         pronoun, personal
#
#           SPACE      _SP         whitespace
# became     VERB       VBD         verb, past tense
# more       ADV        RBR         adverb, comparative
# and        CCONJ      CC          conjunction, coordinating
# more       ADV        RBR         adverb, comparative
# puzzled    ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# .          PUNCT      .           punctuation mark, sentence closer
# Presently  ADV        RB          adverb
# ,          PUNCT      ,           punctuation mark, comma
# he         PRON       PRP         pronoun, personal
# came       VERB       VBD         verb, past tense
# to         ADP        IN          conjunction, subordinating or preposition
# a          DET        DT          determiner
# pond       NOUN       NN          noun, singular or mass
# where      SCONJ      WRB         wh-adverb
# Mr.        PROPN      NNP         noun, proper singular
#
#           SPACE      _SP         whitespace
# McGregor   PROPN      NNP         noun, proper singular
# filled     VERB       VBD         verb, past tense
# his        PRON       PRP$        pronoun, possessive
# water      NOUN       NN          noun, singular or mass
# -          PUNCT      HYPH        punctuation mark, hyphen
# ...
# Mr.        PROPN      NNP         noun, proper singular
# McGregor   PROPN      NNP         noun, proper singular
# hoeing     NOUN       NN          noun, singular or mass
# onions     NOUN       NNS         noun, plural
# .          PUNCT      .           punctuation mark, sentence closer
# His        PRON       PRP$        pronoun, possessive
# back       NOUN       NN          noun, singular or mass
# was        AUX        VBD         verb, past tense
#
#           SPACE      _SP         whitespace
# turned     VERB       VBN         verb, past participle
# towards    ADP        IN          conjunction, subordinating or preposition
# Peter      PROPN      NNP         noun, proper singular
# ,          PUNCT      ,           punctuation mark, comma
# and        CCONJ      CC          conjunction, coordinating
# beyond     ADP        IN          conjunction, subordinating or preposition
# him        PRON       PRP         pronoun, personal
# was        AUX        VBD         verb, past tense
# the        DET        DT          determiner
# gate       NOUN       NN          noun, singular or mass
# !          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# Peter      PROPN      NNP         noun, proper singular
# got        VERB       VBD         verb, past tense
# down       ADP        RP          adverb, particle
# very       ADV        RB          adverb
# quietly    ADV        RB          adverb
# off        ADP        IN          conjunction, subordinating or preposition
# the        DET        DT          determiner
# wheelbarrow NOUN       NN          noun, singular or mass
# ;          PUNCT      :           punctuation mark, colon or ellipsis
# and        CCONJ      CC          conjunction, coordinating
# started    VERB       VBD         verb, past tense
# running    VERB       VBG         verb, gerund or present participle
#
#           SPACE      _SP         whitespace
# as         ADV        RB          adverb
# fast       ADV        RB          adverb
# as         SCONJ      IN          conjunction, subordinating or preposition
# he         PRON       PRP         pronoun, personal
# could      AUX        MD          verb, modal auxiliary
# go         VERB       VB          verb, base form
# ,          PUNCT      ,           punctuation mark, comma
# along      ADP        IN          conjunction, subordinating or preposition
# a          DET        DT          determiner
# straight   ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# walk       NOUN       NN          noun, singular or mass
# behind     ADP        IN          conjunction, subordinating or preposition
# some       DET        DT          determiner
#
#           SPACE      _SP         whitespace
# black      ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# -          PUNCT      HYPH        punctuation mark, hyphen
# currant    NOUN       NN          noun, singular or mass
# bushes     NOUN       NNS         noun, plural
# .          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# Mr.        PROPN      NNP         noun, proper singular
# McGregor   PROPN      NNP         noun, proper singular
# caught     VERB       VBD         verb, past tense
# sight      NOUN       NN          noun, singular or mass
# of         ADP        IN          conjunction, subordinating or preposition
# him        PRON       PRP         pronoun, personal
# at         ADP        IN          conjunction, subordinating or preposition
# the        DET        DT          determiner
# corner     NOUN       NN          noun, singular or mass
# ,          PUNCT      ,           punctuation mark, comma
# but        CCONJ      CC          conjunction, coordinating
# Peter      PROPN      NNP         noun, proper singular
# did        AUX        VBD         verb, past tense
# not        PART       RB          adverb
#
#           SPACE      _SP         whitespace
# care       VERB       VB          verb, base form
# .          PUNCT      .           punctuation mark, sentence closer
# He         PRON       PRP         pronoun, personal
# slipped    VERB       VBD         verb, past tense
# underneath ADP        IN          conjunction, subordinating or preposition
# the        DET        DT          determiner
# gate       NOUN       NN          noun, singular or mass
# ,          PUNCT      ,           punctuation mark, comma
# and        CCONJ      CC          conjunction, coordinating
# was        AUX        VBD         verb, past tense
# safe       ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# at         ADP        IN          conjunction, subordinating or preposition
# last       ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# in         ADP        IN          conjunction, subordinating or preposition
# the        DET        DT          determiner
# wood       NOUN       NN          noun, singular or mass
#
#           SPACE      _SP         whitespace
# outside    ADP        IN          conjunction, subordinating or preposition
# the        DET        DT          determiner
# garden     NOUN       NN          noun, singular or mass
# .          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# Mr.        PROPN      NNP         noun, proper singular
# McGregor   PROPN      NNP         noun, proper singular
# hung       VERB       VBD         verb, past tense
# up         ADP        RP          adverb, particle
# the        DET        DT          determiner
# little     ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# jacket     NOUN       NN          noun, singular or mass
# and        CCONJ      CC          conjunction, coordinating
# the        DET        DT          determiner
# shoes      NOUN       NNS         noun, plural
# for        ADP        IN          conjunction, subordinating or preposition
# a          DET        DT          determiner
# scare      NOUN       NN          noun, singular or mass
# -          PUNCT      HYPH        punctuation mark, hyphen
# crow       NOUN       NN          noun, singular or mass
#
#           SPACE      _SP         whitespace
# to         PART       TO          infinitival "to"
# frighten   VERB       VB          verb, base form
# the        DET        DT          determiner
# blackbirds NOUN       NNS         noun, plural
# .          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# Peter      PROPN      NNP         noun, proper singular
# never      ADV        RB          adverb
# stopped    VERB       VBD         verb, past tense
# running    VERB       VBG         verb, gerund or present participle
# or         CCONJ      CC          conjunction, coordinating
# looked     VERB       VBD         verb, past tense
# behind     ADP        IN          conjunction, subordinating or preposition
# him        PRON       PRP         pronoun, personal
# till       SCONJ      IN          conjunction, subordinating or preposition
# he         PRON       PRP         pronoun, personal
# got        VERB       VBD         verb, past tense
# home       ADV        RB          adverb
# to         ADP        IN          conjunction, subordinating or preposition
#
#           SPACE      _SP         whitespace
# the        DET        DT          determiner
# big        ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# fir        NOUN       NN          noun, singular or mass
# -          PUNCT      HYPH        punctuation mark, hyphen
# tree       NOUN       NN          noun, singular or mass
# .          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# He         PRON       PRP         pronoun, personal
# was        AUX        VBD         verb, past tense
# so         ADV        RB          adverb
# tired      ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# that       SCONJ      IN          conjunction, subordinating or preposition
# he         PRON       PRP         pronoun, personal
# flopped    VERB       VBD         verb, past tense
# down       ADP        RP          adverb, particle
# upon       SCONJ      IN          conjunction, subordinating or preposition
# the        DET        DT          determiner
# nice       ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# soft       ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# sand       NOUN       NN          noun, singular or mass
# on         ADP        IN          conjunction, subordinating or preposition
# the        DET        DT          determiner
#
#           SPACE      _SP         whitespace
# floor      NOUN       NN          noun, singular or mass
# of         ADP        IN          conjunction, subordinating or preposition
# the        DET        DT          determiner
# rabbit     NOUN       NN          noun, singular or mass
# -          PUNCT      HYPH        punctuation mark, hyphen
# hole       NOUN       NN          noun, singular or mass
# and        CCONJ      CC          conjunction, coordinating
# shut       VERB       VBD         verb, past tense
# his        PRON       PRP$        pronoun, possessive
# eyes       NOUN       NNS         noun, plural
# .          PUNCT      .           punctuation mark, sentence closer
# His        PRON       PRP$        pronoun, possessive
# mother     NOUN       NN          noun, singular or mass
# was        AUX        VBD         verb, past tense
# busy       ADJ        JJ          adjective (English), other noun-modifier (Chinese)
#
#           SPACE      _SP         whitespace
# cooking    NOUN       NN          noun, singular or mass
# ;          PUNCT      :           punctuation mark, colon or ellipsis
# she        PRON       PRP         pronoun, personal
# wondered   VERB       VBD         verb, past tense
# what       PRON       WP          wh-pronoun, personal
# he         PRON       PRP         pronoun, personal
# had        AUX        VBD         verb, past tense
# done       VERB       VBN         verb, past participle
# with       ADP        IN          conjunction, subordinating or preposition
# his        PRON       PRP$        pronoun, possessive
# clothes    NOUN       NNS         noun, plural
# .          PUNCT      .           punctuation mark, sentence closer
# It         PRON       PRP         pronoun, personal
# was        AUX        VBD         verb, past tense
# the        DET        DT          determiner
#
#           SPACE      _SP         whitespace
# second     ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# little     ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# jacket     NOUN       NN          noun, singular or mass
# and        CCONJ      CC          conjunction, coordinating
# pair       NOUN       NN          noun, singular or mass
# of         ADP        IN          conjunction, subordinating or preposition
# shoes      NOUN       NNS         noun, plural
# that       PRON       WDT         wh-determiner
# Peter      PROPN      NNP         noun, proper singular
# had        AUX        VBD         verb, past tense
# lost       VERB       VBN         verb, past participle
# in         ADP        IN          conjunction, subordinating or preposition
# a          DET        DT          determiner
#
#           SPACE      _SP         whitespace
# fortnight  NOUN       NN          noun, singular or mass
# !          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# I          PRON       PRP         pronoun, personal
# am         AUX        VBP         verb, non-3rd person singular present
# sorry      ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# to         PART       TO          infinitival "to"
# say        VERB       VB          verb, base form
# that       SCONJ      IN          conjunction, subordinating or preposition
# Peter      PROPN      NNP         noun, proper singular
# was        AUX        VBD         verb, past tense
# not        PART       RB          adverb
# very       ADV        RB          adverb
# well       ADV        RB          adverb
# during     ADP        IN          conjunction, subordinating or preposition
# the        DET        DT          determiner
# evening    NOUN       NN          noun, singular or mass
# .          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# His        PRON       PRP$        pronoun, possessive
# mother     NOUN       NN          noun, singular or mass
# put        VERB       VBD         verb, past tense
# him        PRON       PRP         pronoun, personal
# to         ADP        IN          conjunction, subordinating or preposition
# bed        NOUN       NN          noun, singular or mass
# ,          PUNCT      ,           punctuation mark, comma
# and        CCONJ      CC          conjunction, coordinating
# made       VERB       VBD         verb, past tense
# some       DET        DT          determiner
# camomile   NOUN       NN          noun, singular or mass
# tea        NOUN       NN          noun, singular or mass
# ;          PUNCT      :           punctuation mark, colon or ellipsis
# and        CCONJ      CC          conjunction, coordinating
# she        PRON       PRP         pronoun, personal
# gave       VERB       VBD         verb, past tense
# a          DET        DT          determiner
#
#           SPACE      _SP         whitespace
# dose       NOUN       NN          noun, singular or mass
# of         ADP        IN          conjunction, subordinating or preposition
# it         PRON       PRP         pronoun, personal
# to         ADP        IN          conjunction, subordinating or preposition
# Peter      PROPN      NNP         noun, proper singular
# !          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# '          PART       POS         possessive ending
# One        NUM        CD          cardinal number
# table      NOUN       NN          noun, singular or mass
# -          PUNCT      HYPH        punctuation mark, hyphen
# spoonful   ADJ        JJ          adjective (English), other noun-modifier (Chinese)
# to         PART       TO          infinitival "to"
# be         AUX        VB          verb, base form
# taken      VERB       VBN         verb, past participle
# at         ADP        IN          conjunction, subordinating or preposition
# bed        NOUN       NN          noun, singular or mass
# -          PUNCT      HYPH        punctuation mark, hyphen
# time       NOUN       NN          noun, singular or mass
# .          PUNCT      .           punctuation mark, sentence closer
# '          PUNCT      ''          closing quotation mark
#
#
#          SPACE      _SP         whitespace
# But        CCONJ      CC          conjunction, coordinating
# Flopsy     PROPN      NNP         noun, proper singular
# ,          PUNCT      ,           punctuation mark, comma
# Mopsy      PROPN      NNP         noun, proper singular
# ,          PUNCT      ,           punctuation mark, comma
# and        CCONJ      CC          conjunction, coordinating
# Cotton     PROPN      NNP         noun, proper singular
# -          PUNCT      HYPH        punctuation mark, hyphen
# tail       PROPN      NNP         noun, proper singular
# had        VERB       VBD         verb, past tense
# bread      NOUN       NN          noun, singular or mass
# and        CCONJ      CC          conjunction, coordinating
# milk       NOUN       NN          noun, singular or mass
# and        CCONJ      CC          conjunction, coordinating
#
#           SPACE      _SP         whitespace
# blackberries NOUN       NNS         noun, plural
# for        ADP        IN          conjunction, subordinating or preposition
# supper     NOUN       NN          noun, singular or mass
# .          PUNCT      .           punctuation mark, sentence closer
#
#
#          SPACE      _SP         whitespace
# THE        DET        DT          determiner
# END        PROPN      NNP         noun, proper singular
#
#           SPACE      _SP         whitespace

# %% [markdown]
# POS_counts = doc.count_by(spacy.attrs.POS)
#
# for k, val in sorted(POS_counts.items()):
#     print(f'{k}.  {doc.vocab[k].text:{5}} ---> {val}')

# %%
# provide the frequence list of POS tags from entire document:

POS_counts =  doc.count_by(spacy.attrs.POS)
for k, val in sorted(POS_counts.items()):
    print(f'{k}.  {doc.vocab[k].text:{8}}-----> {val}')
# Out:
# 84.  ADJ     -----> 54
# 85.  ADP     -----> 122
# 86.  ADV     -----> 67
# 87.  AUX     -----> 49
# 89.  CCONJ   -----> 61
# 90.  DET     -----> 90
# 92.  NOUN    -----> 166
# 93.  NUM     -----> 8
# 94.  PART    -----> 29
# 95.  PRON    -----> 109
# 96.  PROPN   -----> 76
# 97.  PUNCT   -----> 173
# 98.  SCONJ   -----> 20
# 100.  VERB    -----> 135
# 103.  SPACE   -----> 99

# %%
# what perc are nouns
count =0
totcount = 0
POS_counts = doc.count_by(spacy.attrs.POS)

for k, val in sorted(POS_counts.items()):
    if doc.vocab[k].text =='NOUN':
        count = val
        totcount = totcount + val
    else:
        totcount = totcount + val

# %%
count
# Out:
# 166

# %%
count/totcount*100
# Out:
# 13.195548489666137

# %%
# display the dependency parse for the third sentence

# %%
displacy.render(doc, style='dep', jupyter=  True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4a6154b92e05431e9f3a1169013a2f34-0" class="displacy" width="189750" height="1012.0" direction="ltr" style="max-width: none; height: 1012.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Tale</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Peter</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Rabbit,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Beatrix</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Potter (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">1902).</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Once</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">upon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">time</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">there</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">were</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">four</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">little</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">Rabbits,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">their</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">names</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">were--</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">
#
#           </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">Flopsy,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">
#        </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">Mopsy,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">
#    </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">Cotton-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">tail,</tspan>
#     <tspan class="displacy-tag" d

# %%
count =0
for entity in doc.ents:
    count+=1
    print(entity , '----->' , str(spacy.explain(entity.label_)))
    if count == 2:
        break
# Out:
# The Tale of Peter Rabbit -----> Titles of books, songs, etc.
# Beatrix Potter -----> People, including fictional

# %%
sentence = [sent for sent in doc.sents]
print(len(sentence))
type(sentence[1])
# Out:
# 55
# spacy.tokens.span.Span

# %%
count =0
for sent in sentence:
    if len(sent.ents) > 0:
        # print(sent)
        count = count +1
print(count)
# Out:
# 23

# %% [markdown]
# ### Challege display :named entity visulization

# %%
displacy.render(sentence[0], style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Tale of Peter Rabbit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# , by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Beatrix Potter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1902
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ).</br></br></div></span>
